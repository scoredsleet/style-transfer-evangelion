# %%
# 1. Copia os arquivos de forma direta e sem esconder erros
# !cp -r /kaggle/input/models/scoredsleet/codigo-lccstyle/pytorch/default/1* /kaggle/working/

# 2. Lista todos os arquivos (o -la mostra até arquivos ocultos para termos certeza)
# !ls -la /kaggle/working/
# Out:
# total 16
# drwxr-xr-x 4 root root 4096 Mar 17 15:24 .
# drwxr-xr-x 5 root root 4096 Mar 17 15:19 ..
# drwxr-xr-x 3 root root 4096 Mar 17 15:24 1
# drwxr-xr-x 2 root root 4096 Mar 17 15:20 .virtual_documents

# %%
# 1. Entra na pasta '1' onde o main.py realmente está guardado
# %cd /kaggle/working/1/

# 2. Lista os arquivos rapidinho só para termos 100% de certeza
# !ls
# Out:
# /kaggle/working/1
# main.py  src  test.py

# %%
# Inicia o treinamento com os pesos ajustados para não derreter os contornos do Evangelion!
# !python main.py --mode train \
    --epochs 30 \
    --batch_size 4 \
    --w_content 3.0 \
    --w_style 5.0 \
    --w_dist 0.05 \
    --lr 0.00005 \
    --content_dir "/kaggle/input/datasets/scoredsleet/evangelion-style-data/data/content" \
    --style_dir "/kaggle/input/datasets/scoredsleet/evangelion-style-data/data/style" \
    --weights_dir "/kaggle/working/pesos_salvos"
# Out:
# ...
#      EVA-LCCStyle: Arbitrary Style Transfer (Neon Genesis Evangelion)
#      Baseado no artigo LCCStyle (Low Computational Complexity)
# ...
#
# [*] Modo Selecionado: TREINAMENTO (Device: cuda)
# Iniciando treinamento por 30 épocas no dispositivo: cuda
# Época [1/30] - Loss Média: 107.8898
# 🌟 Novo recorde! Loss caiu de inf para 107.8898. Salvando pesos...
# Época [2/30] - Loss Média: 93.6052
# 🌟 Novo recorde! Loss caiu de 107.8898 para 93.6052. Salvando pesos...
# Época [3/30] - Loss Média: 85.0392
# 🌟 Novo recorde! Loss caiu de 93.6052 para 85.0392. Salvando pesos...
# Época [4/30] - Loss Média: 75.1371
# 🌟 Novo recorde! Loss caiu de 85.0392 para 75.1371. Salvando pesos...
# Época [5/30] - Loss Média: 70.7960
# 🌟 Novo recorde! Loss caiu de 75.1371 para 70.7960. Salvando pesos...
# Época [6/30] - Loss Média: 68.0667
# 🌟 Novo recorde! Loss caiu de 70.7960 para 68.0667. Salvando pesos...
# Época [7/30] - Loss Média: 66.0841
# ...
